# %% [markdown]
# # Name: Arjun Bhan                  UNI: AB5666

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
import math
batch_size = 64
block_size = 128
max_iters = 5000
eval_interval = 500
learning_rate = 3e-4
"""
Use 'mps' if on a mac as below:

device = 'mps' if torch.backends.mps.is_available() else 'cpu'
"""
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
d_model = 96
n_head = 6
n_layer = 6
dropout = 0.2

torch.manual_seed(1337)

# %%
# !gdown 'https://drive.google.com/uc?export=download&id=1RlmRmXiWVKpZq98ftdtOIdM2lsA1uw3j'
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1RlmRmXiWVKpZq98ftdtOIdM2lsA1uw3j
# To: /content/hemingway.txt
# 100% 133k/133k [00:00<00:00, 93.3MB/s]

# %% [markdown]
# As usual, we read the text file and then get two dictionaries from char to idx and in reverse. char embeddings is what we will use here.

# %%
with open('hemingway.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s]
decode = lambda l: ''.join([itos[i] for i in l])

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

# %%
def get_batch(split):

    data = train_data if split == 'train' else val_data
    ix = torch.randint(0, len(data) - block_size, (batch_size,))

    xb = torch.stack([data[i:i + block_size] for i in ix])

    yb = torch.stack([data[i+1:i + block_size +1] for i in ix])
    xb, yb = xb.to(device), yb.to(device)
    return xb, yb

# %%
@torch.no_grad()
def estimate_loss(model):
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            xb, yb = get_batch(split)
            logits, loss = model(xb,yb)
            losses[k]= loss.item()
        out[split] = losses.mean().item()
    model.train()
    return out

# %%
class Head(nn.Module):
    def __init__(self, d_head):
        super().__init__()
        self.d_head = d_head
        self.W_K = nn.Linear(d_model, d_head, bias = False)
        self.W_Q = nn.Linear(d_model, d_head, bias = False)
        self.W_V = nn.Linear(d_model, d_head, bias = False)
        self.d_head = d_head
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,d = x.shape
        k = self.W_K(x)
        q = self.W_Q(x)
        v = self.W_V(x)
        scores = torch.matmul(q, k.transpose(-2, -1))/(math.sqrt(self.d_head))
        scores = scores.masked_fill(self.tril[:T,:T] == 0, float('-inf'))

        a = F.softmax(scores, dim = -1)

        a = self.dropout(a)

        out = torch.matmul(a, v)
        return out

class MultiHeadAttention(nn.Module):


    def __init__(self, num_heads, d_head):
        super().__init__()
        self.heads = nn.ModuleList([Head(d_head) for _ in range(num_heads)])
        self.W_O = nn.Linear(num_heads * d_head, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([head(x) for head in self.heads], dim = -1)
        out = self.dropout(self.W_O(out))
        return out

# %%
class FeedFoward(nn.Module):


    def __init__(self, d_model):
        super().__init__()
        d_ff = 4 * d_model
        self.ff = nn.Sequential(
            nn.Linear(d_model, d_ff),
            nn.ReLU(),
            nn.Linear(d_ff, d_model),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.ff(x)

# %%
class DecoderBlock(nn.Module):


    def __init__(self, d_model, n_head):
        super().__init__()

        d_head = d_model // n_head
        self.sa = MultiHeadAttention(n_head, d_head)
        self.ff = FeedFoward(d_model)
        self.ln1 = nn.LayerNorm(d_model)
        self.ln2 = nn.LayerNorm(d_model)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ff(self.ln2(x))
        return x

# %%
class GPT(nn.Module):
    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, d_model)
        self.position_embedding_table = nn.Embedding(block_size, d_model)
        self.blocks = nn.Sequential(*[DecoderBlock(d_model, n_head = 8 ) for i in range(n_layer)])
        self.ln = nn.LayerNorm(d_model)
        self.ff = nn.Linear(d_model, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device = idx.device))
        x = tok_emb + pos_emb

        x = self.blocks(x)

        x = self.ln(x)

        logits = self.ff(x)

        if targets is None:
            loss = None
        else:
            B, T, V = logits.shape
            logits = logits.view(B*T, V)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):

        self.eval()
        for _ in range(max_new_tokens):

            idx_cond = idx[:, -block_size:]


            logits, loss = self.forward(idx_cond)


            logits = logits[:, -1,:]


            probs = F.softmax(logits,dim = -1)

            idx_next = torch.multinomial(probs, 1)


            idx = torch.cat([idx, idx_next], dim = 1)
        self.train()
        return idx

# %%
class EarlyStopping:
    def __init__(self, tolerance=5, min_delta=0):
        self.tolerance = tolerance
        self.min_delta = min_delta
        self.counter = 0
        self.early_stop = False

    def __call__(self, train_loss, validation_loss):
        if (validation_loss - train_loss) / train_loss > self.min_delta:
            self.counter += 1
            if self.counter >= self.tolerance:
                self.early_stop = True

# %%
model = GPT().to(device)
tot_param = sum(i.numel() for i in model.parameters() if i.requires_grad)
print('The total number of parameters are', tot_param)

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.9)
early_stopping = EarlyStopping(tolerance=1, min_delta=0.2)

for iter in range(max_iters):

    if iter % eval_interval == 0 or iter == max_iters - 1:
        if iter:
          scheduler.step()
        losses = estimate_loss(model)
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        early_stopping(losses['train'], losses['val'])
        if early_stopping.early_stop:
          print("We stop at epoch {}".format(iter))
          break


    xb, yb = get_batch('train')

    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# The total number of parameters are 693758
# step 0: train loss 4.2657, val loss 4.2684
# step 500: train loss 2.1653, val loss 2.1719
# step 1000: train loss 1.8754, val loss 1.8722
# step 1500: train loss 1.6747, val loss 1.6835
# step 2000: train loss 1.5519, val loss 1.5794
# step 2500: train loss 1.4714, val loss 1.5090
# step 3000: train loss 1.4070, val loss 1.4636
# step 3500: train loss 1.3642, val loss 1.4286
# step 4000: train loss 1.3194, val loss 1.4005
# step 4500: train loss 1.2955, val loss 1.3848
# step 4999: train loss 1.2693, val loss 1.3679

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(model.generate(context, max_new_tokens=10000)[0].tolist()))
open('fake_hemingway.txt', 'w').write(decode(model.generate(context, max_new_tokens=10000)[0].tolist()))
# Out:
# Dom man, "I you rember and shouldid the slank of the firmst so they here the sun raw the pion try against with his could up the last was and a let heard and poing and they were beezfully of the hart betteenes oned it hold.
#
# At the shark's line roped at it of the fish crenbe of the bird and was antimeng Sideso fast the gine line acra his hands that he comps and his lines ave strong foing against dep day and sawrected the geat was shan. Martt down in the water gut best spoppoing acrove it sight one ground and the san's clack on of his were he saw in the yart the gaff it the old morthin fish. It I lmust can do not see so ensiddil eat with now a mall jesched a land knowing all sides old mast the line of does and he dold under his aelins, he thought. Perthing and kill his head from chome and the fish head doark that what the bird it eving. But is vell not see lower oper size and he swaw most the fish right the foot the boat and they did feet his bird and the boy and dank, alway.
#
# Whe boy sould. Juse what he had saited and as the boy for fish, where hough the other tmoagen. Latted that He slank had negr Joush be work whide on it as he said and droved into the boy was always dread-fareshing his bow. He newspelated in he was to sea blue coil and was no fult tow have he duies, he thought. He saw his left too do usel and try his rused. The is shark hip a rober it coilse. Theld man could all his head very there fish as lay carramble the dew was was becar, out he eave toins against the spoing so me. They watched not and I could not rick after and he had for to kills and drew light him the water was meaten me and know back.
#
# "On. The old man's boy Peerhae will although of the from of the fish and pronculing conferly the cold made and hose.
#
# "Be can his ging," he said. "I good oht man't eately him touse hom."
#
# When he felt the sky in time the froost at theirs moves of all the light fish. Eack was line him deft and nothing his bes it going and the would fiers fith when the boy in to getchark frain I this he have in he was good. He can amp-bade of the sea the foot. Fat at chon the shim of the flying through fish as thought he cuned ins.
#
# He challed the head the light on J the wood I wome happen in the sait.
#
# He had ttrankly about it he was sheavy. But he more that surt fish and beging Strosed rose with the wood stray fom the boat. Then it now who water hould to can dot go dray, pluce. The lappe jump. The water of the broat warkes been at him bog a well and aboart it is sturs.
#
# It had mush not on the tair with have, the had out. Then that I was a straight paine mosth it was to strong the did bout the fight spome its how them.
#
# You could left then he was so a man that he had a bone hugans, he thought. He never he turniong against in the skiff all and was sucked of then he skiff it and the looce not.
#
# Und their make he men and hosead. Then he rease is and draist. Each like the elife you bue is aill. And he had he know the old man seen him held in the jarks and the gaine bead's wathing for days.
#
# "Some you," the airpoung."
#
# "Mathing of Degro."
#
# "I can it a mist stran's chearnt of man," the frest of the looked and he glown fing, he thought or mide his good and.
#
# "Veed were bring I wom onde and nother and surfore the crossper stied one fish only with it."
#
# "When then I was ushere the hought. He my fish been alanothing Contwarry on the fish," the old man said. "I his claxe in the back," the old man said. "But it was get out truens befaut them of eile the ir was bast a rest have had befilac. The would of him he even were rulled made too do the hands dripicg on and there boy?
#
# He had new nothing to get. He but dram purhed with the old man lanks his hands flying great and timbes. This ferhan rub of is and the boy have boy userned the boy was beep to pled and had hold up riento work hard almosth they well the wanteder work rippoing. Ca melle.
#
# The down his beauth.
#
# "Betaut the old man to man's keep of is cautink hand."
#
# Just not unt the oarm what is steal frish the knows my on on the fish that I cull to get sart, of man, he thought. I have hooken Just non a purther, and mat in the had untear and not him from to good sell of his souldide, out and line tood get even the bow would about the was not sever and the tillse rest they to iat wook a mard happoon. The manist of the sky. The water swor breaking in a lettlim him out lucking him against to out him. He hay it tunive back.
#
# "He's felh it."
#
# "Had rempiped circlips," he said aloud."
#
# "It know is trose a sinno way in their old the birds in the old man" said. "I not so and they pattire circed the was spowe his fact fat it and down it they and the dives fortaates the nead, toge his befour see houlder much that kess met it with him the boy excevent for straily fish the fish and of them year will bad.
#
# "Vext and great it time it I him the gave him."
#
# "I the tirn ever it far the sarn him again. It was not for manan is not cit?"
#
# "A that not I so tereat. That is fish the big made too see and I have home have a cut of the boat luer congear anyour at where and hand go dreat on his and had brow-so the old of where bow the old beguod too ferve as and he knew it fast and the old man picklan and drank the live stern that he lite would himself of out up. He ad not ream one chet. He tun again and were as gaffoood fish one it raw the side even.
#
# She water whis lines and peogish's but left when the fish lesh one's. Ave it was remembler wentan, bait line and all by timp.
#
# Aling by hot down the line hand. They we sork against one were bed a could thing with that we lasightere the boy care alway as they finst to kill and the back acron a should of strails from and his sartilled bech and the old man new the other oar Ner buise in and the old morn and the lines great have fish. It has do the own it with and the line said his left efto des hooked agen Then was the fooss plagash. He had chaume agao. He abone he peep his right and the ocean over.
#
# When the saw had out I not aloved and his right when in hund every the lines on the started. That carrearing were anAftering against and steery. But was ennowed up the old maned went his could and the stail his elsocks, he thought. My thright it to mortul far fle?
#
# I he thought. Daved tring in they as they fish's slowly you would no not see lolds of the man becut one sarted not ease, porhon arme the othin left tair and The old man had blane it to take of, he thought.
#
# I thought. That poteop when I wile on whis his matten. But was bed.
#
# I know he turne that one of the beate blought the man been his left so them the nart on the line water the bow the skiff.
#
# "Have one the sun on sthooke on the line another and one aloudud. He was not of his no very in the perhap was feeel good flying beeCome out.
#
# "You'ry back," he said "Garbale. "Went or the eat of was stail forear when he act with his swome in the was back. The would not firm anywat over he by eving stray it himself, the old. Thit shark nother though and when he get against they boy tow you learp and one the old men. He not manhich had is and felt.
#
# They boy was eat ranged been happed with his shorted sud and it so thre knife fish that he boy all trust the breeze his giMage been. What boje wited been as man and it was by newsmed, against him lits and his swam his sorm-for had could he see good and the old man, surtily it made remembler upcher.
#
# "No," the old man sturfars back the shark.
#
# There boy and knows. But could on him from lear hands up some by that head left time of the sun and wry it so jumped.
#
# It is. Some excet the sivelide and he is loted the coip. And dif" his that had patere he would the work guld not for made down."
#
# "No," he said. "Now you a good on him of them ceved rome. And his fellent. But the man fist brand and the old man the boy the windered on to be and the hundrew it wight slotern Fiostnes of the strength song hook gars.
#
# "When a knowion have reemembere, he thought."
#
# "Helt the go calme bulg nat, them. When he turted break to go not arm reake in something the boy he did. That would him of enother the bird of the fish is no happhed not he new comp when him he ean ideside a more I could a pirin have ake the old man and from the right on it and theing all the sun up rub; the Marking of the night, he thought.
#
# "Do," that I watched hopen on his beling his breeze. He came usiressalffed bors for it it and strubblack. I was was unwaybecaue was as the water and threwling one sclouds abon, hald letteady.
#
# The jookers in the loome and a new they feside two deve thought.
#
# A the old man's negan had it puslent and he old man sall and he thought looked the old man tememben  the old man aspehed his cailying of the make sterved alongs the bon pothed when the mivem, the tojed vere sually swame in then we comes out and cporting dolphing more a fish with doer in the boy whiter from though praicesed the right and and aloneQ. Fast they did. Whe will in the sunt was right his up his handss ling, ling and only on his saileing anpays the old man was looked platen it cinst from the fly and he sat did.
#
# "That is slowly fathing his neft, he thought. Whe perthaps alcound anot his against and not. They went sun a draw made did in the pippact from out his shars he had a puse in the littled and the first furm and the plund and when ctrong, he thought. Sherews man's. There bell side was a right back to ner-brother. At I mast more be to surn. Then what his fall in a undrew and and his lated the sharks and lightelf moving and kill fath jumped of the fish boat of with his of the boy day was in and it the made time his jumpers of the gron cold hirpor, and he was undeding the same moved the sping beating and he made the brogggen. He it now withor. He water, the old mean again ain will stranesce whan all it man slo with the cord all man the sides and with his is could every to were his jaws geach and dreat tail in him. The's befoater, upich the confuls that he water over the shark cumph and he big.
#
# "He boy had," the old man said.
# 10001

# %%
torch.save(model.state_dict(), 'gpt.pt')
